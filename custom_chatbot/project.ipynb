# %% [markdown]
# # Custom Chatbot Project

# %% [markdown]
# In this project, I'm building a custom chatbot that is able to answer questions related to New York City food scrap drop off sites.
#
# To retrieve the relevant information, I used the data in "nyc_food_scrap_drop_off_sites.csv" file. The file "contains locations, hours, and other information about food scrap drop-off sites in New York City." This dataset is appropriate for my task becasue it contains relevant information.

# %% [markdown]
# ## Data Wrangling

# %%
import pandas as pd
import openai
import numpy as np
import tiktoken
openai.api_base = "https://openai.vocareum.com/v1"
openai.api_key = "YOUR API KEY"

# %%
df = pd.read_csv("./data/nyc_food_scrap_drop_off_sites.csv")

# %%
# add the "text" colum to the dataframe
df["text"] = None

for i, row in df.iterrows():
    df.at[i, "text"] = f"borough: {row['borough']}\n"\
    f"Neighborhood Tabulation Area Name: {row['ntaname']}\n"\
    f"food scrap drop off site: {row['food_scrap_drop_off_site']}\n"\
    f"hosted by: {row['hosted_by']}\n"\
    f"open months: {row['open_months']}\n"\
    f"operation day hours: {row['operation_day_hours']}\n"\
    f"website: {row['website']}\n"\
    f"notes: {row['notes']}\n"

# %%
print(df.at[1, "text"])
# Out:
# borough: Manhattan
# Neighborhood Tabulation Area Name: Inwood
# food scrap drop off site: SE Corner of Broadway & Academy Street
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!

# %% [markdown]
# ## Custom Query Completion

# %%
drop_off_site_question = "In Manhattan borough and East Village Neighborhood Tabulation Area Name, where's the food scrap drop off site?"
host_question = "Who is hosting the food scrap drop off site in Manhattan borough and East Village Neighborhood Tabulation Area Name?"

# %% [markdown]
# ### Generating Embeddings

# %%
EMBEDDING_MODEL_NAME = "text-embedding-ada-002"
# Uncomment the following if you need to use the API to get the embeddings
# batch_size = 100
# embeddings = []
# for i in range(0, len(df), batch_size):
#     # Send text data to OpenAI model to get embeddings
#     response = openai.Embedding.create(
#         input=df.iloc[i:i+batch_size]["text"].tolist(),
#         engine=EMBEDDING_MODEL_NAME
#     )
    
#     # Add embeddings to list
#     embeddings.extend([data["embedding"] for data in response["data"]])

# # Add embeddings list to dataframe
# df["embeddings"] = embeddings
# df
# Out:
#      Unnamed: 0        borough                                     ntaname  \
# 0             0  Staten Island  Grasmere-Arrochar-South Beach-Dongan Hills
# 1             1      Manhattan                                      Inwood
# 2             2       Brooklyn                                  Park Slope
# 3             3      Manhattan                         East Harlem (North)
# 4             4         Queens                                      Corona
# ..          ...            ...                                         ...
# 571         571       Brooklyn                                  Kensington
# 572         572         Queens                   Old Astoria-Hallets Point
# 573         573       Brooklyn                       Crown Heights (North)
# 574         574       Brooklyn                 Windsor Terrace-South Slope
# 575         575          Bronx   University Heights (South)-Morris Heights
#
#                               food_scrap_drop_off_site  \
# 0                                          South Beach
# 1               SE Corner of Broadway & Academy Street
# 2                             Old Stone House Brooklyn
# 3          SE Corner of Pleasant Avenue & E 116 Street
# 4                                       Malcolm X FSDO
# ..                                                 ...
# 571                 Albemarle Road and McDonald Avenue
# 572              NW Corner of 21st Street & 30th Drive
# 573                 Rochester Avenue & St. Johns Place
# 574  *CLOSED FOR THE SEASON* East 4th Street Commun...
# 575                    Community Access - Davidson Ave
#
#                                               location  \
# 0                      21 Robin Road, Staten Island NY
# 1                                                  NaN
# 2                       336 3rd St, Brooklyn, NY 11215
# 3                                                  NaN
# 4             111-26 Northern Blvd, Flushing, NY 11368
# ..                                                 ...
# 571  southwest corner of McDonald Avenue and Albema...
# 572                                                NaN
# 573                                                NaN
# 574                   173 E 4th St, Brooklyn, NY 11218
# 575                                  1750 Davidson Ave
#
#                                             hosted_by      open_months  \
# 0                                   Snug Harbor Youth       Year Round
# 1                            Department of Sanitation       Year Round
# 2                            Old Stone House Brooklyn       Year Round
# 3                            Department of Sanitation       Year Round
# 4             NYC Compost Project Hosted by Big Reuse       Year Round
# ..                                                ...              ...
# 571  NYC Compost Project Hosted by LES Ecology Center       Year Round
# 572                          Department of Sanitation       Year Round
# 573                          Department of Sanitation       Year Round
# 574       Members at East 4th Street Community Garden  April - October
# 575                                           GrowNYC       Year Round
#
#                                    operation_day_hours  \
# 0    Friday (Start Time: 1:30 PM - End Time:  4:30 PM)
# 1                                                 24/7
# 2            24/7 (Start Time: 24/7 - End Time:  24/7)
# 3                                                 24/7
# 4    Tuesdays (Start Time: 12:00 PM - End Time:  2:...
# ..                                                 ...
# 571  Tuesdays (Start Time: 10:00 AM - End Time:  2:...
# 572                                               24/7
# 573                                               24/7
# 574  Wednesdays and Saturdays (Start Time: Wednesda...
# 575  Thursdays (Start Time: 8:30 AM - End Time:  1:...
#
#                                                website  borocd  ...  \
# 0                                      snug-harbor.org     502  ...
# 1                          www.nyc.gov/smartcomposting     112  ...
# 2                                                  NaN     306  ...
# 3                          www.nyc.gov/smartcomposting     111  ...
# 4                                                  NaN     404  ...
# ..                                                 ...     ...  ...
# 571  https://www.lesecologycenter.org/programs/comp...     312  ...
# 572                        www.nyc.gov/smartcomposting     401  ...
# 573                        www.nyc.gov/smartcomposting     308  ...
# 574         https://eastfourthstreetgarden.tumblr.com/     307  ...
# 575                           www.communityaccess.org/     205  ...
#
#      :@computed_region_92fq_4b7q  :@computed_region_sbqj_enih  \
# 0                           14.0                         76.0
# 1                            NaN                          NaN
# 2                           27.0                         50.0
# 3                            NaN                          NaN
# 4                           21.0                         68.0
# ..                           ...                          ...
# 571                         27.0                         39.0
# 572                          NaN                          NaN
# 573                          NaN                          NaN
# 574                         27.0                         45.0
# 575                         29.0                         29.0
#
#      :@computed_region_efsh_h5xi  :@computed_region_f5dn_yrer  \
# 0                        10692.0                         30.0
# 1                            NaN                          NaN
# 2                        17617.0                         14.0
# 3                            NaN                          NaN
# 4                        14510.0                         66.0
# ..                           ...                          ...
# 571                      17620.0                          2.0
# 572                          NaN                          NaN
# 573                          NaN                          NaN
# 574                      17620.0                          9.0
# 575                      10931.0                          6.0
#
#                                                  notes ct2010           bbl  \
# 0                                                  NaN    NaN           NaN
# 1    Download the app to access bins. Accepts all f...    NaN           NaN
# 2                                                  NaN    NaN           NaN
# 3    Download the app to access bins. Accepts all f...    NaN           NaN
# 4                                                  NaN    NaN           NaN
# ..                                                 ...    ...           ...
# 571                Not accepted: meat, bones, or dairy    NaN           NaN
# 572  Download the app to access bins. Accepts all f...    NaN           NaN
# 573  Download the app to access bins. Accepts all f...    NaN           NaN
# 574                Not accepted: meat, bones, or dairy    NaN           NaN
# 575                Not accepted: meat, bones, or dairy  217.0  2.028610e+09
#
#            bin                                               text  \
# 0          NaN  borough: Staten Island\nNeighborhood Tabulatio...
# 1          NaN  borough: Manhattan\nNeighborhood Tabulation Ar...
# 2          NaN  borough: Brooklyn\nNeighborhood Tabulation Are...
# 3          NaN  borough: Manhattan\nNeighborhood Tabulation Ar...
# 4          NaN  borough: Queens\nNeighborhood Tabulation Area ...
# ..         ...                                                ...
# 571        NaN  borough: Brooklyn\nNeighborhood Tabulation Are...
# 572        NaN  borough: Queens\nNeighborhood Tabulation Area ...
# 573        NaN  borough: Brooklyn\nNeighborhood Tabulation Are...
# 574        NaN  borough: Brooklyn\nNeighborhood Tabulation Are...
# 575  2115886.0  borough: Bronx\nNeighborhood Tabulation Area N...
#
#                                             embeddings
# 0    [0.005969604942947626, -0.0260244719684124, 0....
# 1    [-0.0009904223261401057, -0.014946683309972286...
# 2    [0.005709781311452389, -0.040901798754930496, ...
# 3    [0.00042385648703202605, -0.021642452105879784...
# 4    [0.005171763710677624, -0.031190568581223488, ...
# ..                                                 ...
# 571  [0.007184811867773533, -0.026496510952711105, ...
# 572  [0.01071658544242382, -0.02099519968032837, -0...
# 573  [0.008518521673977375, -0.025968298316001892, ...
# 574  [0.0012587112141773105, -0.03266900032758713, ...
# 575  [-0.00013719622802454978, -0.03955645114183426...
#
# [576 rows x 27 columns]

# %%
# df.to_csv("embeddings.csv")

# %%
# Use this cell to load the data without calling the API
df = pd.read_csv("embeddings.csv", index_col=0)
df["embeddings"] = df["embeddings"].apply(eval).apply(np.array)

# %% [markdown]
# ### Retrieve relevant information

# %%
# this function comes from the lesson's material
from openai.embeddings_utils import get_embedding, distances_from_embeddings

def get_rows_sorted_by_relevance(question, df):
    """
    Function that takes in a question string and a dataframe containing
    rows of text and associated embeddings, and returns that dataframe
    sorted from least to most relevant for that question
    """
    
    # Get embeddings for the question text
    question_embeddings = get_embedding(question, engine=EMBEDDING_MODEL_NAME)
    
    # Make a copy of the dataframe and add a "distances" column containing
    # the cosine distances between each row's embeddings and the
    # embeddings of the question
    df_copy = df.copy()
    df_copy["distances"] = distances_from_embeddings(
        question_embeddings,
        df_copy["embeddings"].values,
        distance_metric="cosine"
    )
    
    # Sort the copied dataframe by the distances and return it
    # (shorter distance = more relevant so we sort in ascending order)
    df_copy.sort_values("distances", ascending=True, inplace=True)
    return df_copy

# %%
get_rows_sorted_by_relevance(drop_off_site_question, df)
# Out:
#      Unnamed: 0        borough                                    ntaname  \
# 212         212      Manhattan                               East Village
# 227         227      Manhattan                        East Harlem (South)
# 164         164      Manhattan                        East Harlem (South)
# 61           61      Manhattan                        East Harlem (South)
# 83           83      Manhattan                        East Harlem (North)
# ..          ...            ...                                        ...
# 285         285       Brooklyn                        East Flatbush-Rugby
# 200         200  Staten Island  West New Brighton-Silver Lake-Grymes Hill
# 29           29  Staten Island                              Port Richmond
# 377         377  Staten Island     Annadale-Huguenot-Prince's Bay-Woodrow
# 58           58  Staten Island                    Arden Heights-Rossville
#
#                           food_scrap_drop_off_site  \
# 212                             1st Ave and 1st St
# 227   NW Corner of East 106th Street & Park Avenue
# 164   SE Corner of East 112th Street & Park Avenue
# 61         NW Corner of E 106 Street & Park Avenue
# 83   NE Corner of East 120 Street & Madison Avenue
# ..                                             ...
# 285     *CLOSED FEBRUARY* Wyckoff Farmhouse Museum
# 200                     Grymes Hill Wagner College
# 29           *CLOSED FOR THE SEASON* West Brighton
# 377                                Pleasant Plains
# 58                                   Arden Heights
#
#                                               location  \
# 212  First Avenue between Houston and First Street ...
# 227                 NW East 106th Street & Park Avenue
# 164                 SE East 112th Street & Park Avenue
# 61                                                 NaN
# 83                 NE East 120 Street & Madison Avenue
# ..                                                 ...
# 285              5816 Clarendon Rd, Brooklyn, NY 11203
# 200               1 Campus Rd, Staten Island, NY 10301
# 29                Chappell Street and Henderson Avenue
# 377            Bloomingdale Rd and Drumgoole Road East
# 58                       Arden Avenue and Forest Green
#
#                                             hosted_by  \
# 212  NYC Compost Project Hosted by LES Ecology Center
# 227                          Department of Sanitation
# 164                          Department of Sanitation
# 61                           Department of Sanitation
# 83                           Department of Sanitation
# ..                                                ...
# 285                 Staff at Wychoff Farmhouse Museum
# 200                                    Wagner College
# 29                                  Snug Harbor Youth
# 377                                 Snug Harbor Youth
# 58                                  Snug Harbor Youth
#
#                       open_months  \
# 212                    Year Round
# 227                    Year Round
# 164                    Year Round
# 61                     Year Round
# 83                     Year Round
# ..                            ...
# 285  Year Round (except February)
# 200                September-June
# 29                     Year Round
# 377                    Year Round
# 58                     Year Round
#
#                                    operation_day_hours  \
# 212  Mondays (Start Time: 9:00 AM - End Time:  2:00...
# 227                                               24/7
# 164                                               24/7
# 61                                                24/7
# 83                                                24/7
# ..                                                 ...
# 285     Every day (Start Time: Dawn - End Time:  Dusk)
# 200          24/7 (Start Time: 24/7 - End Time:  24/7)
# 29   Fridays (Start Time: 4:00 PM - End Time:  5:30...
# 377  Mondays (Start Time: 12:00 PM - End Time:  2:0...
# 58   Saturdays (Start Time: 1:00 PM - End Time:  2:...
#
#                                                website  borocd  ...  \
# 212  https://www.lesecologycenter.org/programs/comp...     103  ...
# 227                        www.nyc.gov/smartcomposting     111  ...
# 164                        www.nyc.gov/smartcomposting     111  ...
# 61                         www.nyc.gov/smartcomposting     111  ...
# 83                         www.nyc.gov/smartcomposting     111  ...
# ..                                                 ...     ...  ...
# 285                                  wyckoffmuseum.org     317  ...
# 200                                         wagner.edu     501  ...
# 29                                     snug-harbor.org     501  ...
# 377                           https://snug-harbor.org/     503  ...
# 58                            https://snug-harbor.org/     503  ...
#
#      :@computed_region_sbqj_enih  :@computed_region_efsh_h5xi  \
# 212                          5.0                      11724.0
# 227                         14.0                      12426.0
# 164                         14.0                      12426.0
# 61                           NaN                          NaN
# 83                          16.0                      13093.0
# ..                           ...                          ...
# 285                         40.0                      13827.0
# 200                         74.0                      10691.0
# 29                          74.0                      10697.0
# 377                         77.0                      10696.0
# 58                          77.0                      10699.0
#
#      :@computed_region_f5dn_yrer  \
# 212                         70.0
# 227                          7.0
# 164                          7.0
# 61                           NaN
# 83                           7.0
# ..                           ...
# 285                         61.0
# 200                          4.0
# 29                           4.0
# 377                         15.0
# 58                          15.0
#
#                                                  notes   ct2010 bbl  bin  \
# 212                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 227  Download the app to access bins. Accepts all f...      NaN NaN  NaN
# 164  Download the app to access bins. Accepts all f...      NaN NaN  NaN
# 61   Download the app to access bins. Accepts all f...      NaN NaN  NaN
# 83   Download the app to access bins. Accepts all f...      NaN NaN  NaN
# ..                                                 ...      ...  ..  ...
# 285                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 200                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 29                 Not accepted: meat, bones, or dairy  13301.0 NaN  NaN
# 377                Not accepted: meat, bones, or dairy  20803.0 NaN  NaN
# 58                 Not accepted: meat, bones, or dairy  17007.0 NaN  NaN
#
#                                                   text  \
# 212  borough: Manhattan\nNeighborhood Tabulation Ar...
# 227  borough: Manhattan\nNeighborhood Tabulation Ar...
# 164  borough: Manhattan\nNeighborhood Tabulation Ar...
# 61   borough: Manhattan\nNeighborhood Tabulation Ar...
# 83   borough: Manhattan\nNeighborhood Tabulation Ar...
# ..                                                 ...
# 285  borough: Brooklyn\nNeighborhood Tabulation Are...
# 200  borough: Staten Island\nNeighborhood Tabulatio...
# 29   borough: Staten Island\nNeighborhood Tabulatio...
# 377  borough: Staten Island\nNeighborhood Tabulatio...
# 58   borough: Staten Island\nNeighborhood Tabulatio...
#
#                                             embeddings  distances
# 212  [0.002873592544347048, -0.034644246101379395, ...   0.085361
# 227  [7.570060552097857e-05, -0.03050478734076023, ...   0.087386
# 164  [0.0006138096214272082, -0.027530871331691742,...   0.087589
# 61   [0.0019608139991760254, -0.03150755539536476, ...   0.087756
# 83   [0.0020921695977449417, -0.026472488418221474,...   0.087777
# ..                                                 ...        ...
# 285  [-0.021586209535598755, -0.04849237576127052, ...   0.152359
# 200  [0.022687679156661034, -0.02465062588453293, 0...   0.153001
# 29   [0.008678135462105274, -0.03553430736064911, 0...   0.153249
# 377  [0.005153149366378784, -0.02921896055340767, 0...   0.153859
# 58   [0.01545344851911068, -0.02433036081492901, 0....   0.155707
#
# [576 rows x 28 columns]

# %%
get_rows_sorted_by_relevance(host_question, df)
# Out:
#      Unnamed: 0        borough                                     ntaname  \
# 212         212      Manhattan                                East Village
# 385         385      Manhattan                                East Village
# 227         227      Manhattan                         East Harlem (South)
# 61           61      Manhattan                         East Harlem (South)
# 164         164      Manhattan                         East Harlem (South)
# ..          ...            ...                                         ...
# 0             0  Staten Island  Grasmere-Arrochar-South Beach-Dongan Hills
# 29           29  Staten Island                               Port Richmond
# 445         445          Bronx   University Heights (South)-Morris Heights
# 200         200  Staten Island   West New Brighton-Silver Lake-Grymes Hill
# 58           58  Staten Island                     Arden Heights-Rossville
#
#                            food_scrap_drop_off_site  \
# 212                              1st Ave and 1st St
# 385                     Tompkins Square Greenmarket
# 227    NW Corner of East 106th Street & Park Avenue
# 61          NW Corner of E 106 Street & Park Avenue
# 164    SE Corner of East 112th Street & Park Avenue
# ..                                              ...
# 0                                       South Beach
# 29            *CLOSED FOR THE SEASON* West Brighton
# 445  *CLOSED FOR THE SEASON* Francis Martin Library
# 200                      Grymes Hill Wagner College
# 58                                    Arden Heights
#
#                                               location  \
# 212  First Avenue between Houston and First Street ...
# 385            E 7th St & Avenue A, New York, NY 10009
# 227                 NW East 106th Street & Park Avenue
# 61                                                 NaN
# 164                 SE East 112th Street & Park Avenue
# ..                                                 ...
# 0                      21 Robin Road, Staten Island NY
# 29                Chappell Street and Henderson Avenue
# 445             2150 University Avenue Bronx, NY 10453
# 200               1 Campus Rd, Staten Island, NY 10301
# 58                       Arden Avenue and Forest Green
#
#                                             hosted_by     open_months  \
# 212  NYC Compost Project Hosted by LES Ecology Center      Year Round
# 385  NYC Compost Project Hosted by LES Ecology Center      Year Round
# 227                          Department of Sanitation      Year Round
# 61                           Department of Sanitation      Year Round
# 164                          Department of Sanitation      Year Round
# ..                                                ...             ...
# 0                                   Snug Harbor Youth      Year Round
# 29                                  Snug Harbor Youth      Year Round
# 445                                               NaN      Year Round
# 200                                    Wagner College  September-June
# 58                                  Snug Harbor Youth      Year Round
#
#                                    operation_day_hours  \
# 212  Mondays (Start Time: 9:00 AM - End Time:  2:00...
# 385  Sundays (Start Time: 8:00 AM - End Time:  5:00...
# 227                                               24/7
# 61                                                24/7
# 164                                               24/7
# ..                                                 ...
# 0    Friday (Start Time: 1:30 PM - End Time:  4:30 PM)
# 29   Fridays (Start Time: 4:00 PM - End Time:  5:30...
# 445  Monday (Start Time: 12:00 PM - End Time:  1:00...
# 200          24/7 (Start Time: 24/7 - End Time:  24/7)
# 58   Saturdays (Start Time: 1:00 PM - End Time:  2:...
#
#                                                website  borocd  ...  \
# 212  https://www.lesecologycenter.org/programs/comp...     103  ...
# 385  https://www.lesecologycenter.org/programs/comp...     103  ...
# 227                        www.nyc.gov/smartcomposting     111  ...
# 61                         www.nyc.gov/smartcomposting     111  ...
# 164                        www.nyc.gov/smartcomposting     111  ...
# ..                                                 ...     ...  ...
# 0                                      snug-harbor.org     502  ...
# 29                                     snug-harbor.org     501  ...
# 445      https://www.nypl.org/locations/francis-martin     205  ...
# 200                                         wagner.edu     501  ...
# 58                            https://snug-harbor.org/     503  ...
#
#      :@computed_region_sbqj_enih  :@computed_region_efsh_h5xi  \
# 212                          5.0                      11724.0
# 385                          5.0                      11729.0
# 227                         14.0                      12426.0
# 61                           NaN                          NaN
# 164                         14.0                      12426.0
# ..                           ...                          ...
# 0                           76.0                      10692.0
# 29                          74.0                      10697.0
# 445                         29.0                      10931.0
# 200                         74.0                      10691.0
# 58                          77.0                      10699.0
#
#      :@computed_region_f5dn_yrer  \
# 212                         70.0
# 385                         70.0
# 227                          7.0
# 61                           NaN
# 164                          7.0
# ..                           ...
# 0                           30.0
# 29                           4.0
# 445                          6.0
# 200                          4.0
# 58                          15.0
#
#                                                  notes   ct2010 bbl  bin  \
# 212                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 385                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 227  Download the app to access bins. Accepts all f...      NaN NaN  NaN
# 61   Download the app to access bins. Accepts all f...      NaN NaN  NaN
# 164  Download the app to access bins. Accepts all f...      NaN NaN  NaN
# ..                                                 ...      ...  ..  ...
# 0                                                  NaN      NaN NaN  NaN
# 29                 Not accepted: meat, bones, or dairy  13301.0 NaN  NaN
# 445                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 200                Not accepted: meat, bones, or dairy      NaN NaN  NaN
# 58                 Not accepted: meat, bones, or dairy  17007.0 NaN  NaN
#
#                                                   text  \
# 212  borough: Manhattan\nNeighborhood Tabulation Ar...
# 385  borough: Manhattan\nNeighborhood Tabulation Ar...
# 227  borough: Manhattan\nNeighborhood Tabulation Ar...
# 61   borough: Manhattan\nNeighborhood Tabulation Ar...
# 164  borough: Manhattan\nNeighborhood Tabulation Ar...
# ..                                                 ...
# 0    borough: Staten Island\nNeighborhood Tabulatio...
# 29   borough: Staten Island\nNeighborhood Tabulatio...
# 445  borough: Bronx\nNeighborhood Tabulation Area N...
# 200  borough: Staten Island\nNeighborhood Tabulatio...
# 58   borough: Staten Island\nNeighborhood Tabulatio...
#
#                                             embeddings  distances
# 212  [0.002873592544347048, -0.034644246101379395, ...   0.089472
# 385  [0.007218232378363609, -0.02844279259443283, -...   0.091638
# 227  [7.570060552097857e-05, -0.03050478734076023, ...   0.092051
# 61   [0.0019608139991760254, -0.03150755539536476, ...   0.092296
# 164  [0.0006138096214272082, -0.027530871331691742,...   0.093557
# ..                                                 ...        ...
# 0    [0.005969604942947626, -0.0260244719684124, 0....   0.152279
# 29   [0.008678135462105274, -0.03553430736064911, 0...   0.153174
# 445  [-0.004862444009631872, -0.034543685615062714,...   0.153215
# 200  [0.022687679156661034, -0.02465062588453293, 0...   0.154811
# 58   [0.01545344851911068, -0.02433036081492901, 0....   0.154900
#
# [576 rows x 28 columns]

# %% [markdown]
# ### Create a custom prompt

# %%
# this is from the course material
def create_prompt(question, df, max_token_count):
    """
    Given a question and a dataframe containing rows of text and their
    embeddings, return a text prompt to send to a Completion model
    """
    # Create a tokenizer that is designed to align with our embeddings
    tokenizer = tiktoken.get_encoding("cl100k_base")
    
    # Count the number of tokens in the prompt template and question
    prompt_template = """
Answer the question based on the context below, and if the question
can't be answered based on the context, say "I don't know"

Context: 

{}

---

Question: {}
Answer:"""
    
    current_token_count = len(tokenizer.encode(prompt_template)) + \
                            len(tokenizer.encode(question))
    
    context = []
    for text in get_rows_sorted_by_relevance(question, df)["text"].values:
        
        # Increase the counter based on the number of tokens in this row
        text_token_count = len(tokenizer.encode(text))
        current_token_count += text_token_count
        
        # Add the row of text to the list if we haven't exceeded the max
        if current_token_count <= max_token_count:
            context.append(text)
        else:
            break

    return prompt_template.format("\n\n###\n\n".join(context), question)

# %%
print(create_prompt(drop_off_site_question, df, 1800))
# Out:
# Answer the question based on the context below, and if the question
# can't be answered based on the context, say "I don't know"
#
# Context:
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Village
# food scrap drop off site: 1st Ave and 1st St
# hosted by: NYC Compost Project Hosted by LES Ecology Center
# open months: Year Round
# operation day hours: Mondays (Start Time: 9:00 AM - End Time:  2:00 PM)
# website: https://www.lesecologycenter.org/programs/compost/compost-drop-off-locations/
# notes: Not accepted: meat, bones, or dairy
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: NW Corner of East 106th Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of East 112th Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: NW Corner of E 106 Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of East 120 Street & Madison Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 112 Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of East 130th Street & 5th Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 120 Street & Madision Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 127 Street & Lexington Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 130 Street & 5 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 106 Street & 3 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of East 127th Street & Lexington Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 100 Street & 1 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of East 100th Street & 1st Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Village
# food scrap drop off site: Tompkins Square Greenmarket
# hosted by: NYC Compost Project Hosted by LES Ecology Center
# open months: Year Round
# operation day hours: Sundays (Start Time: 8:00 AM - End Time:  5:00 PM)
# website: https://www.lesecologycenter.org/programs/compost/compost-drop-off-locations/
# notes: Not accepted: meat, bones, or dairy
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of East 106th Street & 3rd Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: SW Corner of E 118 Street & 1 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ---
#
# Question: In Manhattan borough and East Village Neighborhood Tabulation Area Name, where's the food scrap drop off site?
# Answer:

# %%
print(create_prompt(host_question, df, 1800))
# Out:
# Answer the question based on the context below, and if the question
# can't be answered based on the context, say "I don't know"
#
# Context:
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Village
# food scrap drop off site: 1st Ave and 1st St
# hosted by: NYC Compost Project Hosted by LES Ecology Center
# open months: Year Round
# operation day hours: Mondays (Start Time: 9:00 AM - End Time:  2:00 PM)
# website: https://www.lesecologycenter.org/programs/compost/compost-drop-off-locations/
# notes: Not accepted: meat, bones, or dairy
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Village
# food scrap drop off site: Tompkins Square Greenmarket
# hosted by: NYC Compost Project Hosted by LES Ecology Center
# open months: Year Round
# operation day hours: Sundays (Start Time: 8:00 AM - End Time:  5:00 PM)
# website: https://www.lesecologycenter.org/programs/compost/compost-drop-off-locations/
# notes: Not accepted: meat, bones, or dairy
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: NW Corner of East 106th Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: NW Corner of E 106 Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of East 112th Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 112 Street & Park Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of East 120 Street & Madison Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of East 130th Street & 5th Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 106 Street & 3 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 130 Street & 5 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 120 Street & Madision Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NW Corner of E 109 Street & 2 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of E 100 Street & 1 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: NE Corner of E 127 Street & Lexington Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Midtown-Turtle Bay
# food scrap drop off site: Dag Hammarskjold Plaza Greenmarket
# hosted by: GrowNYC
# open months: Year Round
# operation day hours: Wednesdays (Start Time: 8:00 AM - End Time:  12:30 PM)
# website: grownyc.org/compost
# notes: Not accepted: meat, bones, or dairy
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (South)
# food scrap drop off site: SE Corner of East 100th Street & 1st Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ###
#
# borough: Manhattan
# Neighborhood Tabulation Area Name: East Harlem (North)
# food scrap drop off site: SW Corner of E 118 Street & 1 Avenue
# hosted by: Department of Sanitation
# open months: Year Round
# operation day hours: 24/7
# website: www.nyc.gov/smartcomposting
# notes: Download the app to access bins. Accepts all food scraps, including meat and dairy. Do not leave food scraps outside of bin!
#
#
# ---
#
# Question: Who is hosting the food scrap drop off site in Manhattan borough and East Village Neighborhood Tabulation Area Name?
# Answer:

# %% [markdown]
# ## Custom Performance Demonstration
#
# In the cells below, demonstrate the performance of your custom query using at least 2 questions. For each question, show the answer from a basic `Completion` model query as well as the answer from your custom query.

# %%
COMPLETION_MODEL_NAME = "gpt-3.5-turbo-instruct"

def answer_question(
    question, df, max_prompt_tokens=1800, max_answer_tokens=150
):
    """
    Given a question, a dataframe containing rows of text, and a maximum
    number of desired tokens in the prompt and response, return the
    answer to the question according to an OpenAI Completion model
    
    If the model produces an error, return an empty string
    """
    
    prompt = create_prompt(question, df, max_prompt_tokens)
    
    try:
        response = openai.Completion.create(
            model=COMPLETION_MODEL_NAME,
            prompt=prompt,
            max_tokens=max_answer_tokens
        )
        return response["choices"][0]["text"].strip()
    except Exception as e:
        print(e)
        return ""

# %% [markdown]
# ### Question 1

# %%
drop_off_site_prompt = f"""
Question: {drop_off_site_question}
Answer:
"""
initial_drop_off_site_answer = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=drop_off_site_prompt,
    max_tokens=150
)["choices"][0]["text"].strip()

# %%
custom_drop_off_site_answer = answer_question(drop_off_site_question, df)

# %% [markdown]
# ### Question 2

# %%
host_prompt = f"""
Question: {host_question}
Answer:
"""
initial_host_prompt_answer = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=host_prompt,
    max_tokens=150
)["choices"][0]["text"].strip()

# %%
custom_host_prompt_answer = answer_question(host_question, df)

# %%
print(f"""
{drop_off_site_question}

Original Answer: {initial_drop_off_site_answer}
Custom Answer:   {custom_drop_off_site_answer}

#######

{host_question}

Original Answer: {initial_host_prompt_answer}
Custom Answer:   {custom_host_prompt_answer}
""")
# Out:
# In Manhattan borough and East Village Neighborhood Tabulation Area Name, where's the food scrap drop off site?
#
# Original Answer: According to the NYC Zero Waste website, the nearest food scrap drop off site in the East Village Neighborhood Tabulation Area Name is located at the Union Square Greenmarket on Union Square West between 14th and 15th Streets.
# Custom Answer:   Tompkins Square Greenmarket.
#
# #######
#
# Who is hosting the food scrap drop off site in Manhattan borough and East Village Neighborhood Tabulation Area Name?
#
# Original Answer: The NYC Compost Project Host Partner on Governor's Island is hosting the food scrap drop off site in Manhattan borough and East Village Neighborhood Tabulation Area Name.
# Custom Answer:   NYC Compost Project Hosted by LES Ecology Center

# %% [markdown]
# **Question 1**: The original answer seems to be incorrect, but the custom answer exists in the dataset. That said, the custom answer does not list all sites.
# **Question 2**: The original answer does not actually contain the host name, but the custom answer is correct and concise.
